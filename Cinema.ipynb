# %% [markdown]
# ## Análise de dados de filmes exibidos no Brasil de 2009 à 2019
# Com base nos dados da Ancine https://oca.ancine.gov.br/cinema
#
# Arquivos 2120_xlsx

# %% [markdown]
# # Importação

# %%
import pandas as pd
import matplotlib.pyplot
# %matplotlib inline

# %%
#pulando as duas primeiras linhas e excluíndo as 20 últimas linhas
df = pd.read_excel("2120.xlsx", skiprows=2, skipfooter=20)

df.head()
# Out:
#    Ano de exibição              Título da obra         CPB/ROE    Gênero  \
# 0             2019   120 Batimentos Por Minuto  E1700453800000    Ficção
# 1             2019                     3 Faces  E1800494900000    Ficção
# 2             2019            45 Dias Sem Você  B1800586000000    Ficção
# 3             2019    A 100 Passos De Um Sonho  E1402795100000    Ficção
# 4             2019  A Abelhinha Maya - O Filme  E1800136100000  Animação
#
#   País(es) produtor(es) da obra Nacionalidade da obra Data de lançamento  \
# 0                        França           Estrangeira              43104
# 1                           Irã           Estrangeira              43559
# 2                        Brasil            Brasileira              43601
# 3                Estados Unidos           Estrangeira              41879
# 4                      Alemanha           Estrangeira              43237
#
#   Empresa distribuidora Origem da empresa distribuidora  \
# ...

# %% [markdown]
# ## Exploração

# %%
# Exibir as 5 últimas linhas
df.tail()
# Out:
#       Ano de exibição       Título da obra         CPB/ROE        Gênero  \
# 7076             2009          Xuxa Gêmeas  B0600616500000        Ficção
# 7077             2009         Zico na Rede  B0901041400000  Documentário
# 7078             2009             À Deriva  B0901015000000        Ficção
# 7079             2009     É Proibido Fumar  B0901108700000        Ficção
# 7080             2009  Última Parada - 174  B0800914800000        Ficção
#
#      País(es) produtor(es) da obra Nacionalidade da obra Data de lançamento  \
# 7076                        Brasil            Brasileira              39066
# 7077                        Brasil            Brasileira              39997
# 7078        Brasil, Estados Unidos            Brasileira              40025
# 7079                        Brasil            Brasileira              40151
# 7080                        Brasil            Brasileira              39745
#
#      Empresa distribuidora Origem da empresa distribuidora  \
# ...

# %%
df.tail(21)
# Out:
#       Ano de exibição                   Título da obra         CPB/ROE  \
# 7060             2009         Vicky Cristina Barcelona  E1500741400000
# 7061             2009                       Vigaristas  E1500623800000
# 7062             2009                          Vila 21  E1600637700000
# 7063             2009               Violência Gratuita  E1600584300000
# 7064             2009                            Vitus  E1600639100000
# 7065             2009                         Viva Voz  B0300007100000
# 7066             2009                Você é tão Bonito  E1600592600000
# 7067             2009                  Vocês, os Vivos  E1600637600000
# 7068             2009                           Volver  E1600639300000
# 7069             2009                               W.  E1600639400000
# 7070             2009   Waldick, Sempre no meu Coração  B0800852600000
# 7071             2009                           Wall-E  E1500366400000
# ...

# %%
# Verificar todos os tipos das colunas
df.dtypes
# Out:
# Ano de exibição                     int64
# Título da obra                     object
# CPB/ROE                            object
# Gênero                             object
# País(es) produtor(es) da obra      object
# Nacionalidade da obra              object
# Data de lançamento                 object
# Empresa distribuidora              object
# Origem da empresa distribuidora    object
# Público no ano de exibição         object
# Renda (R$) no ano de exibição      object
# dtype: object

# %%
# converter os campos data de lançamento, público no ano de exibição e renda no ano de exibição
df["Data de lançamento"] = pd.to_datetime(df["Data de lançamento"])
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~\anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1373     else:
# -> 1374         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1375
#
# ~\anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648         if res is None:
# --> 649             raise ParserError("Unknown string format: %s", timestr)
#     650
#
# ParserError: Unknown string format: Relançamento
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ...

# %%
# Vamos tentar indenficar o problema da coluna data de lançamento
df["Data de lançamento"].value_counts()
# Out:
# Relançamento    198
# 42341            33
# 41264            33
# 41607            29
# 41215            27
#                ...
# 41922             1
# 40328             1
# 43280             1
# 41913             1
# 42188             1
# Name: Data de lançamento, Length: 878, dtype: int64

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Ano de exibição              Título da obra         CPB/ROE  \
# 0                2019   120 Batimentos Por Minuto  E1700453800000
# 1                2019                     3 Faces  E1800494900000
# 2                2019            45 Dias Sem Você  B1800586000000
# 3                2019    A 100 Passos De Um Sonho  E1402795100000
# 4                2019  A Abelhinha Maya - O Filme  E1800136100000
# ...               ...                         ...             ...
# 7076             2009                 Xuxa Gêmeas  B0600616500000
# 7077             2009                Zico na Rede  B0901041400000
# 7078             2009                    À Deriva  B0901015000000
# 7079             2009            É Proibido Fumar  B0901108700000
# 7080             2009         Última Parada - 174  B0800914800000
#
#             Gênero País(es) produtor(es) da obra Nacionalidade da obra  \
# ...

# %% [markdown]
# ## Decisão sobre dados incorretos/faltantes/divergentes

# %%
# Vamos excluir a coluna data de lançamento pois ela não veio com os parâmentros corretos
df_novo = df.drop(columns=["Data de lançamento"])

# %%
df_novo.head()
# Out:
#    Ano de exibição              Título da obra         CPB/ROE    Gênero  \
# 0             2019   120 Batimentos Por Minuto  E1700453800000    Ficção
# 1             2019                     3 Faces  E1800494900000    Ficção
# 2             2019            45 Dias Sem Você  B1800586000000    Ficção
# 3             2019    A 100 Passos De Um Sonho  E1402795100000    Ficção
# 4             2019  A Abelhinha Maya - O Filme  E1800136100000  Animação
#
#   País(es) produtor(es) da obra Nacionalidade da obra Empresa distribuidora  \
# 0                        França           Estrangeira             Imovision
# 1                           Irã           Estrangeira             Imovision
# 2                        Brasil            Brasileira               O2 Play
# 3                Estados Unidos           Estrangeira                Disney
# 4                      Alemanha           Estrangeira              Playarte
#
#   Origem da empresa distribuidora Público no ano de exibição  \
# ...

# %%
# Quais os anos tiveram mais filmes lançados
df_novo["Ano de exibição"].value_counts()
# Out:
# 2015    794
# 2016    767
# 2018    707
# 2017    703
# 2019    683
# 2014    677
# 2009    588
# 2013    573
# 2011    562
# 2012    517
# 2010    510
# Name: Ano de exibição, dtype: int64

# %%
# Vamos plotar um gráfico com os lançamentos por ano
df_novo["Ano de exibição"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Quantos filmes brasileiros e estrageiros?
df['Nacionalidade da obra'].value_counts()
# Out:
# Estrangeira    4960
# Brasileira     2121
# Name: Nacionalidade da obra, dtype: int64
